# %%
# %run Load_Data.ipynb import *

# %%
plt.plot(CH4)

# %%
temp_filtered = bsnb.lowpass(CH4,0.1,order=2,fs=fs,use_filtfilt=True)

# %%
# %matplotlib
plt.plot(temp_filtered)
# Out:
# Using matplotlib backend: Qt5Agg

# %%
freq,power=bsnb.plotfft(temp_filtered,1)

# %%
# %matplotlib
plt.plot(freq,power)
# Out:
# Using matplotlib backend: Qt5Agg
