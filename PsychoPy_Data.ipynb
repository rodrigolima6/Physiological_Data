# %%
import os,glob
import pandas as pd

# %%
path = 'C:\\Users\\Rodrigo\\Desktop\\PhD\\1st Study\\'

os.chdir(path)
data=pd.read_excel(path+"PsychoPy_data.xlsx")

# %%
data
# Out:
#                                 categories                           videos  \
# 0   Materials/B/films_social_positive.xlsx  EMDB/B/Social Positive/4007.avi
# 1   Materials/B/films_social_positive.xlsx  EMDB/B/Social Positive/4006.avi
# 2   Materials/B/films_social_positive.xlsx  EMDB/B/Social Positive/4009.avi
# 3   Materials/B/films_social_positive.xlsx  EMDB/B/Social Positive/4008.avi
# 4   Materials/B/films_social_positive.xlsx  EMDB/B/Social Positive/4005.avi
# 5            Materials/B/films_horror.xlsx           EMDB/B/Horror/1005.avi
# 6            Materials/B/films_horror.xlsx           EMDB/B/Horror/1009.avi
# 7            Materials/B/films_horror.xlsx           EMDB/B/Horror/1007.avi
# 8            Materials/B/films_horror.xlsx           EMDB/B/Horror/1008.avi
# 9            Materials/B/films_horror.xlsx           EMDB/B/Horror/1006.avi
# 10           Materials/B/films_erotic.xlsx           EMDB/B/Erotic/2006.avi
# ...
