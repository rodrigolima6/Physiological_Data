# %%
# %run Load_Data.ipynb import *
from Process_Features import *

# %%
videos=list()
markers=list()
onset=list()
offset=list()
for timestamp,markers in zip(timestamps,marker):
    if(markers[1] == '1' and "baseline" in markers[0]):
        offset.append(timestamp)
        videos.append(markers[0])
    if (markers[1] == '1' and "baseline" not in markers[0]):
        offset.append(timestamp)
        videos.append(markers[0].split("/")[2]+"/"+markers[0].split("/")[3])
    if(markers[1] == '0'):
        onset.append(timestamp)

# %%
d={'Time':time_Opensignals,'ECG':CH1,'EDA':CH2,'RESP':CH3,'TEMP':CH4,'fNIRS_RED':CH5,'fNIRS_IRED':CH6}
Signals=pd.DataFrame(data=d)
Signals
# Out:
#                 Time      ECG     EDA     RESP       TEMP  fNIRS_RED  \
# 0           0.000000  0.00557  4.4006  1.54678  32.360699   0.015000
# 1           0.001000  0.00449  4.3976  1.54962  32.378601   0.015000
# 2           0.002001  0.00359  4.4044  1.55534  32.360699   0.015008
# 3           0.003001  0.00341  4.4033  1.55214  32.383099   0.015008
# 4           0.004002  0.00270  4.4182  1.54861  32.339901   0.015007
# ...              ...      ...     ...      ...        ...        ...
# 2944187  2945.330387  0.00431  7.7793  1.60922  32.805901   0.018326
# 2944188  2945.331388  0.00431  7.7782  1.60931  32.792500   0.018319
# 2944189  2945.332388  0.00431  7.7709  1.61064  32.772999   0.018319
# 2944190  2945.333388  0.00503  7.7698  1.60876  32.719101   0.016946
# 2944191  2945.334389  0.00557  7.7778  1.60904  32.765499   0.016946
#
#          fNIRS_IRED
# 0          0.049214
# 1          0.049214
# 2          0.049131
# 3          0.049131
# 4          0.049074
# ...

# %%
EEG_Signals = pd.DataFrame.from_dict(EEG_data)
EEG_Signals.insert(0,'Time',time_EEG)
EEG_Signals
# Out:
#                Time          EEG_1         EEG_2         EEG_3         EEG_4  \
# 0          0.000000 -286883.968750 -36441.175781 -31070.976562 -27701.501953
# 1          0.004000 -286896.062500 -36437.136719 -31072.591797 -27703.654297
# 2          0.008000 -286786.750000 -36437.671875 -31069.902344 -27703.654297
# 3          0.012000 -286549.156250 -36431.750000 -31058.603516 -27696.125000
# 4          0.016000 -286729.625000 -36431.750000 -31055.105469 -27694.511719
# ...             ...            ...           ...           ...           ...
# 736379  2945.515997 -256120.312500 -27441.335938 -21830.402344 -23052.669922
# 736380  2945.519997 -256320.156250 -27442.951172 -21824.484375 -23048.099609
# 736381  2945.523997 -256373.218750 -27446.722656 -21832.285156 -23054.283203
# 736382  2945.527997 -256400.968750 -27454.798828 -21841.431641 -23067.460938
# 736383  2945.531997 -256207.578125 -27455.068359 -21846.003906 -23070.958984
#
# ...

# %%
onset_index=list()
offset_index=list()

# %%
for i in range(0,len(onset)):
    onset_index.append(np.where(time_Opensignals>=onset[i])[0][0])
    offset_index.append(np.where(time_Opensignals<=offset[i])[0][-1])

# %%
marker
# Out:
# [['baseline', '0'],
#  ['baseline', '1'],
#  ['EMDB/A/Horror/1002.avi', '0'],
#  ['EMDB/A/Horror/1002.avi', '1'],
#  ['EMDB/A/Horror/1004.avi', '0'],
#  ['EMDB/A/Horror/1004.avi', '1'],
#  ['EMDB/A/Horror/1000.avi', '0'],
#  ['EMDB/A/Horror/1000.avi', '1'],
#  ['EMDB/A/Horror/1001.avi', '0'],
#  ['EMDB/A/Horror/1001.avi', '1'],
#  ['EMDB/A/Horror/1003.avi', '0'],
#  ['EMDB/A/Horror/1003.avi', '1'],
#  ['EMDB/A/Erotic/2001.avi', '0'],
#  ['EMDB/A/Erotic/2001.avi', '1'],
#  ['EMDB/A/Erotic/2004.avi', '0'],
#  ['EMDB/A/Erotic/2004.avi', '1'],
#  ['EMDB/A/Erotic/2000.avi', '0'],
#  ['EMDB/A/Erotic/2000.avi', '1'],
#  ['EMDB/A/Erotic/2003.avi', '0'],
#  ['EMDB/A/Erotic/2003.avi', '1'],
#  ['EMDB/A/Erotic/2002.avi', '0'],
#  ['EMDB/A/Erotic/2002.avi', '1'],
#  ['EMDB/A/Social Negative/3003.avi', '0'],
#  ['EMDB/A/Social Negative/3003.avi', '1'],
#  ['EMDB/A/Social Negative/3002.avi', '0'],
#  ['EMDB/A/Social Negative/3002.avi', '1'],
#  ['EMDB/A/Social Negative/3001.avi', '0'],
# ...

# %%
for i in range(0,len(onset)):
    print(offset[i]-onset[i])
# Out:
# 180.00400843672105
# 40.21010189194931
# 39.764943411108106
# 40.124065607378725
# 40.69994934918941
# 40.41506684932392
# 40.13610309327487
# 40.13403391290922
# 40.130320348078385
# 40.653548489004606
# 40.46176630666014
# 41.739760593976825
# 41.56742322735954
# 41.19453426159453
# 40.220387794455746
# 40.58603312887135
# 40.37409253764781
# 40.61692033614963
# 40.45737604831811
# 40.217181624873774
# 40.73635050421581
# 40.72894657438155
# 40.526481893321034
# 40.48569907984347
# 41.6186635417107
# 40.331193744263146

# %%
offset
# Out:
# [184.13584527687635,
#  559.3517384112929,
#  700.8572024340683,
#  823.5294141568593,
#  930.6507804692956,
#  1036.338330171362,
#  1125.4588198946149,
#  1253.2812602040067,
#  1358.518643372663,
#  1473.073702229187,
#  1566.9778425134136,
#  1673.8994831188465,
#  1776.2690269686573,
#  1874.6233360745828,
#  1966.0776503780507,
#  2049.264906536031,
#  2141.335481998656,
#  2229.289207280439,
#  2311.2753555224335,
#  2400.096283384948,
#  2478.6328081221727,
#  2560.669487785228,
#  2649.440263523051,
#  2736.627609868505,
#  2825.365070322121,
#  2907.81781604173]

# %%
events_diff = list()
for i in range(0,len(onset)):
    events_diff.append(offset[i]-onset[i])
events_diff
# Out:
# [180.00400843672105,
#  40.21010189194931,
#  39.764943411108106,
#  40.124065607378725,
#  40.69994934918941,
#  40.41506684932392,
#  40.13610309327487,
#  40.13403391290922,
#  40.130320348078385,
#  40.653548489004606,
#  40.46176630666014,
#  41.739760593976825,
#  41.56742322735954,
#  41.19453426159453,
#  40.220387794455746,
#  40.58603312887135,
#  40.37409253764781,
#  40.61692033614963,
#  40.45737604831811,
#  40.217181624873774,
#  40.73635050421581,
#  40.72894657438155,
#  40.526481893321034,
#  40.48569907984347,
#  41.6186635417107,
#  40.331193744263146]

# %%
epochs = nk.epochs_create(df,events=onset_index,sampling_rate=fs,epochs_start=0,epochs_end=events_diff)
epochs
# Out:
# {'1':                   Time      ECG     EDA     RESP       TEMP  fNIRS_RED  \
#  0.000000      3.958753 -0.00530  5.1323  1.70279  34.442902   0.053972
#  0.001000      3.959753 -0.00413  5.1247  1.69446  34.478199   0.053972
#  0.002000      3.960754 -0.00341  5.1285  1.69482  34.430698   0.053966
#  0.003000      3.961754 -0.00332  5.1498  1.69620  34.303699   0.053966
#  0.004000      3.962754 -0.00323  5.1353  1.69794  34.470501   0.053944
#  ...                ...      ...     ...      ...        ...        ...
#  179.999101  183.991007 -0.00786  2.1126  1.30421  34.763699   0.056651
#  180.000101  183.992007 -0.00737  2.1217  1.30719  34.694500   0.056684
#  180.001101  183.993007 -0.00593  2.1126  1.30833  34.720600   0.056684
#  180.002101  183.994008 -0.00602  2.1339  1.30655  34.782200   0.056708
#  180.003101  183.995008 -0.00737  2.1103  1.30975  34.728298   0.056708
#
#              fNIRS_IRED   Index Label
#  0.000000      0.189088    3958     1
# ...

# %%
for i, epoch in enumerate (epochs):
    epoch = epochs[epoch]  # iterate epochs",

    epoch = epoch[['ECG']]  # Select relevant columns",
    
    title = pictures[i]
    
    plt.figure()
    plt.plot(epoch)
    plt.title(title)# Plot scaled signals"
# Out:
# C:\ProgramData\Anaconda3\envs\1st Study\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
pictures[-1]
