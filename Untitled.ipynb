# %%
import numpy as np
import biosignalsnotebooks as bsnb
import os
import lib
from lib.biosignals import *
from lib.acquisition import *
from lib.sensors import *
import scipy as sc
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import json

# %%
file_path = "C:/Users/Rodrigo/Downloads/opensignals_98d331205532_2021-06-11_08-16-21.txt"

# %%
data,header = bsnb.load(file_path,get_header=True)

# %%
plt.figure()
plt.plot(data["CH2"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sensor = ECG(data["CH1"],header["sampling rate"],header["resolution"][0])

# %%
ecg = sensor.data
fs = sensor.fs
resolution = sensor.resolution

# %%
time=bsnb.generate_time(ecg,fs)

# %%
peaks = ni.panthomkins.panthomkins(ecg,fs,8,30)

# %%
plt.figure()
plt.plot(time,ecg,'k')
for i in range(0,len(peaks)):
    plt.plot(time[peaks[i]],ecg[peaks[i]],'r',marker='o')
# Out:
# <img src="data:image/png;base64,..." width="640">
